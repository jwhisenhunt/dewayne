# %% [markdown]
# <a href="https://colab.research.google.com/github/jwhisenhunt/dewayne/blob/main/heretic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U heretic-llm

# %% [markdown]
# Change model below

# %%
# !heretic jwhisenhunt/dew
# Out:
# Streaming output truncated to the last 5000 lines.
#   * attn.o_proj.min_weight = 0.07
#   * attn.o_proj.min_weight_distance = 6.60
#   * mlp.down_proj.max_weight = 0.84
#   * mlp.down_proj.max_weight_position = 30.90
#   * mlp.down_proj.min_weight = 0.42
#   * mlp.down_proj.min_weight_distance = 10.20
# * Resetting model...
# * Abliterating...
# * Evaluating...
#   * Obtaining first-token probability distributions...
#   * KL divergence: 0.1970
#   * Counting model refusals...
#   * Refusals: 93/100
#
# Elapsed time: 22m 4s
# Estimated remaining time: 7m 21s
# Resident system RAM: 3.34 GB
# Allocated GPU VRAM: 7.56 GB
# Reserved GPU VRAM: 10.87 GB
#
# Running trial 151 of 200...
# * Parameters:
#   * direction_index = 18.60
#   * attn.o_proj.max_weight = 1.08
#   * attn.o_proj.max_weight_position = 34.87
#   * attn.o_proj.min_weight = 0.74
#   * attn.o_proj.min_weight_distance = 11.35
#   * mlp.down_proj.max_weight = 1.09
#   * mlp.down_proj.max_weight_position = 32.91
# ...
